# %%
import matplotlib.pyplot as plt
from root_pandas import read_root
import mdst
# Out:
# Welcome to JupyROOT 6.24/00

# %%
plt.style.use("belle2")

# %%
df = read_root('~/sad14/Bu2DK_pi.root')

# %%
for column in df.columns:
    print(column)
# Out:
# __experiment__
# __run__
# __event__
# __production__
# __candidate__
# __ncandidates__
# __weight__
# D_K_kaonID
# D_K_pionID
# D_K_protonID
# D_K_muonID
# D_K_electronID
# D_K_electronID_noTOP
# D_K_deuteronID
# D_K_binaryPID_211_13
# D_K_binaryPID_211_321
# D_K_binaryPID_211_2212
# D_K_binaryPID_321_2212
# D_K_dr
# D_K_dx
# D_K_dy
# D_K_dz
# D_K_d0
# D_K_z0
# D_K_pValue
# D_K_ndf
# D_K_nCDCHits
# D_K_nPXDHits
# D_K_nSVDHits
# D_K_nVXDHits
# D_K_px
# D_K_py
# D_K_pz
# D_K_pt
# D_K_p
# D_K_E
# D_K_mcE
# D_K_mcP
# D_K_mcPT
# D_K_mcPX
# D_K_mcPY
# D_K_mcPZ
# D_K_mcPhi
# D_K_isSignal
# D_K_mcErrors
# D_K_mcPDG
# D_pi_kaonID
# D_pi_pionID
# D_pi_protonID
# D_pi_muonID
# D_pi_electronID
# D_pi_electronID_noTOP
# D_pi_deuteronID
# D_pi_binaryPID_211_13
# D_pi_binaryPID_211_321
# D_pi_binaryPID_211_2212
# D_pi_binaryPID_321_2212
# D_pi_dr
# D_pi_dx
# D_pi_dy
# D_pi_dz
# D_pi_d0
# D_pi_z0
# D_pi_pValue
# D_pi_ndf
# D_pi_nCDCHits
# D_pi_nPXDHits
# D_pi_nSVDHits
# D_pi_nVXDHits
# D_pi_px
# D_pi_py
# D_pi_pz
# D_pi_pt
# D_pi_p
# D_pi_E
# D_pi_mcE
# D_pi_mcP
# D_pi_mcPT
# D_pi_mcPX
# D_pi_mcPY
# D_pi_mcPZ
# D_pi_mcPhi
# D_pi_isSignal
# D_pi_mcErrors
# D_pi_mcPDG
# D_pit_kaonID
# D_pit_pionID
# D_pit_protonID
# D_pit_muonID
# D_pit_electronID
# D_pit_electronID_noTOP
# D_pit_deuteronID
# D_pit_binaryPID_211_13
# D_pit_binaryPID_211_321
# D_pit_binaryPID_211_2212
# D_pit_binaryPID_321_2212
# D_pit_dr
# D_pit_dx
# D_pit_dy
# D_pit_dz
# D_pit_d0
# D_pit_z0
# D_pit_pValue
# D_pit_ndf
# D_pit_nCDCHits
# D_pit_nPXDHits
# D_pit_nSVDHits
# D_pit_nVXDHits
# D_pit_px
# D_pit_py
# D_pit_pz
# D_pit_pt
# D_pit_p
# D_pit_E
# D_pit_mcE
# D_pit_mcP
# D_pit_mcPT
# D_pit_mcPX
# D_pit_mcPY
# D_pit_mcPZ
# D_pit_mcPhi
# D_pit_isSignal
# D_pit_mcErrors
# D_pit_mcPDG
# pi_kaonID
# pi_pionID
# pi_protonID
# pi_muonID
# pi_electronID
# pi_electronID_noTOP
# pi_deuteronID
# pi_binaryPID_211_13
# pi_binaryPID_211_321
# pi_binaryPID_211_2212
# pi_binaryPID_321_2212
# pi_dr
# pi_dx
# pi_dy
# pi_dz
# pi_d0
# pi_z0
# pi_pValue
# pi_ndf
# pi_nCDCHits
# pi_nPXDHits
# pi_nSVDHits
# pi_nVXDHits
# pi_px
# pi_py
# pi_pz
# pi_pt
# pi_p
# pi_E
# pi_mcE
# pi_mcP
# pi_mcPT
# pi_mcPX
# pi_mcPY
# pi_mcPZ
# pi_mcPhi
# pi_isSignal
# pi_mcErrors
# pi_mcPDG
# D_M
# D_ErrM
# D_SigM
# D_InvM
# D_px
# D_py
# D_pz
# D_pt
# D_p
# D_E
# D_mcE
# D_mcP
# D_mcPT
# D_mcPX
# D_mcPY
# D_mcPZ
# D_mcPhi
# D_isSignal
# D_mcErrors
# D_mcPDG
# D_distance
# D_significanceOfDistance
# D_dx
# D_dy
# D_dz
# D_x
# D_y
# D_z
# D_x_uncertainty
# D_y_uncertainty
# D_z_uncertainty
# D_dr
# D_dphi
# D_dcosTheta
# D_prodVertexX
# D_prodVertexY
# D_prodVertexZ
# D_prodVertexXErr
# D_prodVertexYErr
# D_prodVertexZErr
# D_chiProb
# D_mcDecayVertexX
# D_mcDecayVertexY
# D_mcDecayVertexZ
# D_mcDecayVertexFromIPDistance
# D_mcDecayVertexRho
# D_mcProductionVertexX
# D_mcProductionVertexY
# D_mcProductionVertexZ
# Mbc
# deltaE
# px
# py
# pz
# pt
# p
# E
# mcE
# mcP
# mcPT
# mcPX
# mcPY
# mcPZ
# mcPhi
# isSignal
# mcErrors
# mcPDG
# distance
# significanceOfDistance
# dx
# dy
# dz
# x
# y
# z
# x_uncertainty
# y_uncertainty
# z_uncertainty
# dr
# dphi
# dcosTheta
# prodVertexX
# prodVertexY
# prodVertexZ
# prodVertexXErr
# prodVertexYErr
# prodVertexZErr
# chiProb
# mcDecayVertexX
# mcDecayVertexY
# mcDecayVertexZ
# mcDecayVertexFromIPDistance
# mcDecayVertexRho
# mcProductionVertexX
# mcProductionVertexY
# mcProductionVertexZ

# %%
df['pi_pionID'].hist(bins=100, range=(0, 1))
plt.xlabel(r'$\pi$ PID of bachelor pion')
plt.ylabel('Number of candidates')
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %%
df.hist('Mbc', bins=100, range=(5.2, 5.3))
plt.xlabel(r'M$_{\rm bc}$ [GeV/c$^{2}$]')
plt.ylabel('Number of candidates')
plt.xlim(5.2, 5.29)
# Out:
# (5.2, 5.29)

# %%
df["Mbc"].describe()
# Out:
# count    30657.000000
# mean         5.279643
# std          0.002611
# min          5.255168
# 25%          5.277893
# 50%          5.279645
# 75%          5.281386
# max          5.289578
# Name: Mbc, dtype: float64

# %%
df.hist('D_M', bins=100, range=(1.8, 1.9))
plt.xlabel(r'$_{K^{+}\pi^{-}\pi^{-}}$ [GeV/c$^{2}$]')
plt.ylabel('Number of candidates')
plt.xlim(1.8,1.9)
# Out:
# (1.8, 1.9)

# %%
df["D_M"].describe()
# Out:
# count    30657.000000
# mean         1.869395
# std          0.004066
# min          1.858100
# 25%          1.866860
# 50%          1.869469
# 75%          1.871984
# max          1.880738
# Name: D_M, dtype: float64

# %%
df.hist('deltaE', bins=100, range=(-0.1, 0.1))
plt.xlabel(r'$\Delta E$ [GeV]')
plt.ylabel('Number of candidates')
plt.xlim(-0.1, 0.1)
# Out:
# (-0.1, 0.1)

# %%
df["deltaE"].describe()
# Out:
# count    26901.000000
# mean        -0.008655
# std          0.050846
# min         -0.506804
# 25%         -0.006992
# 50%         -0.000347
# 75%          0.005633
# max          0.468070
# Name: deltaE, dtype: float64
