# %%
import matplotlib.pyplot as plt
from root_pandas import read_root
import mdst

# %%
plt.style.use("belle2")

# %%
df = read_root('~/sad15/sad/kaon6/kaongen.root')

# %%
for column in df.columns:
    print(column)
# Out:
# __experiment__
# __run__
# __event__
# __production__
# __candidate__
# __ncandidates__
# __weight__
# D_K_px
# D_K_py
# D_K_pz
# D_K_pt
# D_K_p
# D_K_E
# D_K_mcE
# D_K_mcP
# D_K_mcPT
# D_K_mcPX
# D_K_mcPY
# D_K_mcPZ
# D_K_mcPhi
# D_K_isSignal
# D_K_mcErrors
# D_K_mcPDG
# D_K_electronID
# D_K_muonID
# D_K_pionID
# D_K_kaonID
# D_K_protonID
# D_K_deuteronID
# D_K_binaryPID_11_211
# D_K_binaryPID_13_211
# D_K_binaryPID_211_321
# D_K_binaryPID_321_2212
# D_K_binaryPID_211_2212
# D_K_dr
# D_K_dx
# D_K_dy
# D_K_dz
# D_K_d0
# D_K_z0
# D_K_pValue
# D_K_ndf
# D_K_nCDCHits
# D_K_nPXDHits
# D_K_nSVDHits
# D_K_nVXDHits
# D_pi_px
# D_pi_py
# D_pi_pz
# D_pi_pt
# D_pi_p
# D_pi_E
# D_pi_mcE
# D_pi_mcP
# D_pi_mcPT
# D_pi_mcPX
# D_pi_mcPY
# D_pi_mcPZ
# D_pi_mcPhi
# D_pi_isSignal
# D_pi_mcErrors
# D_pi_mcPDG
# D_pi_electronID
# D_pi_muonID
# D_pi_pionID
# D_pi_kaonID
# D_pi_protonID
# D_pi_deuteronID
# D_pi_binaryPID_11_211
# D_pi_binaryPID_13_211
# D_pi_binaryPID_211_321
# D_pi_binaryPID_321_2212
# D_pi_binaryPID_211_2212
# D_pi_dr
# D_pi_dx
# D_pi_dy
# D_pi_dz
# D_pi_d0
# D_pi_z0
# D_pi_pValue
# D_pi_ndf
# D_pi_nCDCHits
# D_pi_nPXDHits
# D_pi_nSVDHits
# D_pi_nVXDHits
# D_pit_px
# D_pit_py
# D_pit_pz
# D_pit_pt
# D_pit_p
# D_pit_E
# D_pit_mcE
# D_pit_mcP
# D_pit_mcPT
# D_pit_mcPX
# D_pit_mcPY
# D_pit_mcPZ
# D_pit_mcPhi
# D_pit_isSignal
# D_pit_mcErrors
# D_pit_mcPDG
# D_pit_electronID
# D_pit_muonID
# D_pit_pionID
# D_pit_kaonID
# D_pit_protonID
# D_pit_deuteronID
# D_pit_binaryPID_11_211
# D_pit_binaryPID_13_211
# D_pit_binaryPID_211_321
# D_pit_binaryPID_321_2212
# D_pit_binaryPID_211_2212
# D_pit_dr
# D_pit_dx
# D_pit_dy
# D_pit_dz
# D_pit_d0
# D_pit_z0
# D_pit_pValue
# D_pit_ndf
# D_pit_nCDCHits
# D_pit_nPXDHits
# D_pit_nSVDHits
# D_pit_nVXDHits
# K_px
# K_py
# K_pz
# K_pt
# K_p
# K_E
# K_mcE
# K_mcP
# K_mcPT
# K_mcPX
# K_mcPY
# K_mcPZ
# K_mcPhi
# K_isSignal
# K_mcErrors
# K_mcPDG
# K_electronID
# K_muonID
# K_pionID
# K_kaonID
# K_protonID
# K_deuteronID
# K_binaryPID_11_211
# K_binaryPID_13_211
# K_binaryPID_211_321
# K_binaryPID_321_2212
# K_binaryPID_211_2212
# K_dr
# K_dx
# K_dy
# K_dz
# K_d0
# K_z0
# K_pValue
# K_ndf
# K_nCDCHits
# K_nPXDHits
# K_nSVDHits
# K_nVXDHits
# D_px
# D_py
# D_pz
# D_pt
# D_p
# D_E
# D_mcE
# D_mcP
# D_mcPT
# D_mcPX
# D_mcPY
# D_mcPZ
# D_mcPhi
# D_isSignal
# D_mcErrors
# D_mcPDG
# D_distance
# D_significanceOfDistance
# D_dx
# D_dy
# D_dz
# D_x
# D_y
# D_z
# D_x_uncertainty
# D_y_uncertainty
# D_z_uncertainty
# D_dr
# D_dphi
# D_dcosTheta
# D_prodVertexX
# D_prodVertexY
# D_prodVertexZ
# D_prodVertexXErr
# D_prodVertexYErr
# D_prodVertexZErr
# D_chiProb
# D_mcDecayVertexX
# D_mcDecayVertexY
# D_mcDecayVertexZ
# D_mcDecayVertexFromIPDistance
# D_mcDecayVertexRho
# D_mcProductionVertexX
# D_mcProductionVertexY
# D_mcProductionVertexZ
# D_M
# D_ErrM
# D_SigM
# D_InvM
# px
# py
# pz
# pt
# p
# E
# mcE
# mcP
# mcPT
# mcPX
# mcPY
# mcPZ
# mcPhi
# isSignal
# mcErrors
# mcPDG
# distance
# significanceOfDistance
# dx
# dy
# dz
# x
# y
# z
# x_uncertainty
# y_uncertainty
# z_uncertainty
# dr
# dphi
# dcosTheta
# prodVertexX
# prodVertexY
# prodVertexZ
# prodVertexXErr
# prodVertexYErr
# prodVertexZErr
# chiProb
# mcDecayVertexX
# mcDecayVertexY
# mcDecayVertexZ
# mcDecayVertexFromIPDistance
# mcDecayVertexRho
# mcProductionVertexX
# mcProductionVertexY
# mcProductionVertexZ
# Mbc
# deltaE

# %%
df['K_kaonID'].hist(bins=100, range=(0, 1))
plt.xlabel('K PID of bachelor kaon')
plt.ylabel('Number of candidates')
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %%
df.hist('Mbc', bins=100, range=(5.2, 5.3))
plt.xlabel(r'M$_{\rm bc}$ [GeV/c$^{2}$]')
plt.ylabel('Number of candidates')
plt.xlim(5.2, 5.29)
# Out:
# (5.2, 5.29)

# %%
df["Mbc"].describe()
# Out:
# count    22554.000000
# mean         5.272512
# std          0.017678
# min          4.173381
# 25%          5.270867
# 50%          5.278120
# 75%          5.281280
# max          5.289742
# Name: Mbc, dtype: float64

# %%
df.hist('D_M', bins=100, range=(1.8, 1.9))
plt.xlabel(r'$_{K^{+}\pi^{-}\pi^{-}}$ [GeV/c$^{2}$]')
plt.ylabel('Number of candidates')
plt.xlim(1.8,1.9)
# Out:
# (1.8, 1.9)

# %%
df["D_M"].describe()
# Out:
# count    22554.000000
# mean         1.868724
# std          0.024880
# min          1.561333
# 25%          1.866220
# 50%          1.869464
# 75%          1.872481
# max          4.229418
# Name: D_M, dtype: float64

# %%
df.hist('deltaE', bins=100, range=(-0.1, 0.1))
plt.xlabel(r'$\Delta E$ [GeV]')
plt.ylabel('Number of candidates')
plt.xlim(-0.1, 0.1)
# Out:
# (-0.1, 0.1)

# %%
df["deltaE"].describe()
# Out:
# count    22554.000000
# mean        -0.154375
# std          0.180193
# min         -2.157224
# 25%         -0.292009
# 50%         -0.154728
# 75%          0.004205
# max          2.966071
# Name: deltaE, dtype: float64
